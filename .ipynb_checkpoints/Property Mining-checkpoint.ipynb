# %%
import spacy
from spacy import displacy
import json
import en_core_web_sm

nlp = en_core_web_sm.load()

# %% [markdown]
# ***
# Test propositions for property mining
# ***

# %%
sentence_group_1 = ["The whale is an animal.",
"The blue whale is an animal.",
"The whale is a quadrupedal mammal.",
"The chameleon is a polychromatic arboreal insectivore.",
"Carnivorous spiders are common.",
"All cephalopods are nocturnal.",
"The majority of cephalopods are nocturnal.",
"Some cephalopods are nocturnal.",
"No cephalopods are nocturnal.",
"Most terrestrial gastropods are hermaphrodites.",
"The simplest gastropods are the limpets and abalone.",
"A cephalopod is any member of the molluscan class Cephalopoda such as a squid, octopus, cuttlefish, or nautilus.",
"Gastropods were described as gastropodes by Georges Cuiver.",
"Cephalopods are widely regarded as the most intelligent of the invertebrates."]

sentence_group_2 = ["The fastest biped is the ostrich.",
"Not all tetrapods are quadrupeds and not all quadrupeds are tetrapods.",
"A tripod stance is a behaviour in which quadruped animals rear up on their hind legs and use their tail to support their weight.",
"Brontosaurus (meaning \"thunder lizard\" from Greek βροντή, \"thunder\" and σαῦρος, \"lizard\") is a genus of gigantic quadruped sauropod dinosaurs.",
"Conrad Gessner (1516–1565) was a Swiss naturalist and bibliographer and one of founding figures of modern zoology.",
"Sound waves with frequency above 20 kHz are called ultrasonic waves and are inaudble to humans, but some animals, like bats and dolphins, use them.",
"A timer is a kind of clock for measuring time intervals, often with an audible alarm that the time is up.",
"There is a debate among audiophiles on whether there is an audible difference between tubes and transistors in sound equipment.",
"A Geiger counter is an instrument that measures ionizing radiation such as alpha particles, beta particles, or gamma rays. The radiation sensor produces a series of audible clicks when radiation is present.",
"Autophagy is the process that cells use to break down and recycle cellular components."]

# %% [markdown]
# ***
# Helpers
# ***

# %%
# https://spacy.io/api/top-level#displacy_options
def visualize(doc):
    options={
        "compact":True,
        "distance":100,
    }
    displacy.render(doc, style='dep',jupyter=True,options=options)    
    
def describe(sentence):
    doc = nlp((sentence))
    visualize(doc)
    print(json.dumps(doc.to_json(), indent=1))    
    
def first_or_none(lst):
    return None if len(lst) == 0 else lst[0]    

def flatten(l):
    return [item for sublist in l for item in sublist]

# %% [markdown]
# ***
# Functions for parsing Spacy dependency tree into properties
# ***

# %%
def children_for(json_doc, head_id, recursive=False):
    results = []
    
    for x in json_doc["tokens"]:
        if x["head"] == head_id and x["id"] != head_id:
            results.append(x)
            
    if recursive and len(results) > 0:
        return results + flatten([children_for(json_doc, r["id"], True) for r in results])
    else:
        return results

def find_token_by_attr(tokens, attr, value):
    results = [t for t in tokens if t[attr] == value]
    return first_or_none(results)

def filter_token_by_attr(tokens, attr, value):
    return [t for t in tokens if t[attr] != value]

def filter_token_by_attrs(tokens, k_v_pairs):
    for key, value in k_v_pairs:
        tokens = filter_token_by_attr(tokens, key, value)
    return tokens

def get_verbs(json_doc, only=None):
    results = []
    for x in json_doc["tokens"]:
        value = value_for_token(x, json_doc)
        is_verb = x["pos"] == "VERB"
        include = only is None or value in only
        if is_verb and include:
            results.append(x)
    return results

def sorted_values(tokens, json_doc):
    return [value_for_token(t, json_doc) for t in sorted(tokens, key=lambda w: w["id"])]

def value_for_token(token, json_doc):
    return json_doc["text"][token["start"]:token["end"]].lower()

# %%
def mine(json_doc):
    results = []
    
    for verb in get_verbs(json_doc, ["is", "are", "were"]):
        children = children_for(json_doc, verb["id"])
        subject = find_token_by_attr(children, "dep", "nsubj")        
        other = filter_token_by_attrs(children, [("dep", "nsubj"),("pos", "PUNCT")])
        
        if not subject:
            continue
                    

        subject_deps = children_for(json_doc, subject["id"])
        subject_deps = filter_token_by_attrs(subject_deps, [("pos", "DET"),("pos", "PUNCT")])
        word = [subject] + subject_deps
        
        properties = []
        
        for o in other:
            properties.append(o)            
            other_deps = children_for(json_doc, o["id"], True)
            properties += filter_token_by_attrs(other_deps, [("pos", "DET")])
            
        word = sorted_values(word, json_doc)
        properties = sorted_values(properties, json_doc)
            
        results.append({
            "word":word,
            "properties":properties
        })
        
    return results

# %%
sentence_group_3 = [
    "An otolith, also called statoconium or otoconium or statolith, is a calcium carbonate structure in the saccule or utricle of the inner ear, specifically in the vestibular system of vertebrates."    
]

for sentence in sentence_group_2:
    doc = nlp((sentence))
    json_doc = doc.to_json()
    
    print()
    print(json_doc["text"])
    print()
    print(mine(json_doc))
    # print(json.dumps(mine(json_doc), indent=1))
# Out:
# The fastest biped is the ostrich.
#
# [{'word': ['fastest', 'biped'], 'properties': ['ostrich']}]
#
# Not all tetrapods are quadrupeds and not all quadrupeds are tetrapods.
#
# [{'word': ['not', 'tetrapods'], 'properties': ['quadrupeds', 'and', 'not', 'quadrupeds', 'are', 'tetrapods', '.']}, {'word': ['not', 'quadrupeds'], 'properties': ['tetrapods']}]
#
# A tripod stance is a behaviour in which quadruped animals rear up on their hind legs and use their tail to support their weight.
#
# [{'word': ['tripod', 'stance'], 'properties': ['behaviour', 'in', 'quadruped', 'animals', 'rear', 'up', 'on', 'hind', 'legs', 'and', 'use', 'tail', 'to', 'support', 'weight']}]
#
# Brontosaurus (meaning "thunder lizard" from Greek βροντή, "thunder" and σαῦρος, "lizard") is a genus of gigantic quadruped sauropod dinosaurs.
#
# [{'word': ['brontosaurus', 'lizard', 'thunder'], 'properties': ['genus', 'of', 'gigantic', 'quadruped', 'sauropod', 'dinosaurs']}]
#
# Conrad Gessner (1516–1565) was a Swiss naturalist and bibliographer and one of founding figures of modern zoology.
#
# []
#
# Sound waves with frequency above 20 kHz are called ultrasonic waves and are inaudble to humans, but some animals, like bats and dolphins, use them.
#
# []
#
# A timer is a kind of clock for measuring time intervals, often with an audible alarm that the time is up.
#
# [{'word': ['timer'], 'properties': ['kind', 'of', 'clock', 'for', 'measuring', 'time', 'intervals', ',', 'often', 'with', 'audible', 'alarm', 'time', 'is', 'up']}, {'word': ['time'], 'properties': ['that', 'up']}]
#
# There is a debate among audiophiles on whether there is an audible difference between tubes and transistors in sound equipment.
#
# []
#
# A Geiger counter is an instrument that measures ionizing radiation such as alpha particles, beta particles, or gamma rays. The radiation sensor produces a series of audible clicks when radiation is present.
#
# [{'word': ['geiger', 'counter'], 'properties': ['instrument', 'measures', 'ionizing', 'radiation', 'such', 'as', 'alpha', 'particles', ',', 'beta', 'particles', ',', 'or', 'gamma', 'rays']}, {'word': ['radiation'], 'properties': ['when', 'present']}]
#
# Autophagy is the process that cells use to break down and recycle cellular components.
#
# [{'word': ['autophagy'], 'properties': ['process', 'cells', 'use', 'to', 'break', 'down', 'and', 'recycle', 'cellular', 'components']}]

# %%
describe(sentence_group_3[0])
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e5fe0b2e3d5b42bc94c14679c70c0836-0" class="displacy" width="3050" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">An</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">otolith,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">also</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">called</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">statoconium</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">otoconium</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">statolith,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">calcium</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">carbonate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">structure</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">saccule</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1750">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1750">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">utricle</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1950">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">inner</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">ear,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2350">specifically</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2350">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2550">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2650">vestibular</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">system</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2950">vertebrates.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2950">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e5fe0b2e3d5b42bc94c14679c70c0836-0-0" stroke-width="2px" d="M62,302.0 62,285.3333333333333 135.0,285.3333333333333 135.0,302.0" fill="none" stroke="currentColor"/>
# {
#  "text": "An otolith, also called statoconium or otoconium or statolith, is a calcium carbonate structure in the saccule or utricle of the inner ear, specifically in the vestibular system of vertebrates.",
#  "ents": [],
#  "sents": [
#   {
#    "start": 0,
#    "end": 193
#   }
#  ],
#  "tokens": [
#   {
#    "id": 0,
#    "start": 0,
#    "end": 2,
#    "pos": "DET",
#    "tag": "DT",
#    "dep": "det",
#    "head": 1
#   },
#   {
#    "id": 1,
#    "start": 3,
#    "end": 10,
#    "pos": "NOUN",
#    "tag": "NN",
#    "dep": "nsubj",
#    "head": 11
#   },
#   {
#    "id": 2,
#    "start": 10,
#    "end": 11,
#    "pos": "PUNCT",
#    "tag": ",",
#    "dep": "punct",
#    "head": 1
#   },
#   {
#    "id": 3,
#    "start": 12,
#    "end": 16,
#    "pos": "ADV",
#    "tag": "RB",
#    "dep": "advmod",
#    "head": 4
#   },
#   {
#    "id": 4,
#    "start": 17,
#    "end": 23,
#    "pos": "VERB",
#    "tag": "VBN",
#    "dep": "acl",
#    "head": 1
#   },
#   {
#    "id": 5,
#    "start": 24,
#    "end": 35,
#    "pos": "NOUN",
#    "tag": "NN",
#    "dep": "oprd",
#    "head": 4
#   },
#   {
#    "id": 6,
#    "start": 36,
#    "end": 38,
#    "pos": "CCONJ",
#    "tag": "CC",
#    "dep": "cc",
#    "head": 5
#   },
#   {
#    "id": 7,
#    "start": 39,
#    "end": 48,
#    "pos": "NOUN",
#    "tag": "NN",
#    "dep": "conj",
#    "head": 5
#   },
#   {
#    "id": 8,
#    "start": 49,
#    "end": 51,
#    "pos": "CCONJ",
#    "tag": "CC",
#    "dep": "cc",
#    "head": 7
#   },
#   {
#    "id": 9,
#    "start": 52,
#    "end": 61,
#    "pos": "NOUN",
#    "tag": "NN",
#    "dep": "conj",
#    "head": 7
#   },
#   {
#    "id": 10,
#    "start": 61,
#    "end": 62,
#    "pos": "PUNCT",
#    "tag": ",",
#    "dep": "punct",
#    "head": 11
#   },
#   {
#    "id": 11,
#    "start": 63,
#    "end": 65,
#    "pos": "VERB",
#    "tag": "VBZ",
#    "dep": "ROOT",
#    "head": 11
#   },
#   {
#    "id": 12,
#    "start": 66,
#    "end": 67,
#    "pos": "DET",
#    "tag": "DT",
#    "dep": "det",
#    "head": 15
#   },
#   {
#    "id": 13,
#    "start": 68,
#    "end": 75,
#    "pos": "NOUN",
#    "tag": "NN",
#    "dep": "compound",
#    "head": 14
#   },
#   {
#    "id": 14,
#    "start": 76,
#    "end": 85,
#    "pos": "NOUN",
#    "tag": "NN",
#    "dep": "compound",
#    "head": 15
#   },
#   {
#    "id": 15,
#    "start": 86,
#    "end": 95,
#    "pos": "NOUN",
#    "tag": "NN",
#    "dep": "attr",
#    "head": 11
#   },
#   {
#    "id": 16,
#    "start": 96,
#    "end": 98,
#    "pos": "ADP",
#    "tag": "IN",
#    "dep": "prep",
#    "head": 15
#   },
#   {
#    "id": 17,
#    "start": 99,
#    "end": 102,
#    "pos": "DET",
#    "tag": "DT",
#    "dep": "det",
#    "head": 18
#   },
#   {
#    "id": 18,
#    "start": 103,
#    "end": 110,
#    "pos": "NOUN",
#    "tag": "NN",
#    "dep": "pobj",
#    "head": 16
#   },
#   {
#    "id": 19,
#    "start": 111,
#    "end": 113,
#    "pos": "CCONJ",
#    "tag": "CC",
#    "dep": "cc",
#    "head": 18
#   },
#   {
#    "id": 20,
#    "start": 114,
#    "end": 121,
#    "pos": "NOUN",
#    "tag": "NN",
#    "dep": "conj",
#    "head": 18
#   },
#   {
#    "id": 21,
#    "start": 122,
#    "end": 124,
#    "pos": "ADP",
#    "tag": "IN",
#    "dep": "prep",
#    "head": 18
#   },
#   {
#    "id": 22,
#    "start": 125,
#    "end": 128,
#    "pos": "DET",
#    "tag": "DT",
#    "dep": "det",
#    "head": 24
#   },
#   {
#    "id": 23,
#    "start": 129,
#    "end": 134,
#    "pos": "ADJ",
#    "tag": "JJ",
#    "dep": "amod",
#    "head": 24
#   },
#   {
#    "id": 24,
#    "start": 135,
#    "end": 138,
#    "pos": "NOUN",
#    "tag": "NN",
#    "dep": "pobj",
#    "head": 21
#   },
#   {
#    "id": 25,
#    "start": 138,
#    "end": 139,
#    "pos": "PUNCT",
#    "tag": ",",
#    "dep": "punct",
#    "head": 11
#   },
#   {
#    "id": 26,
#    "start": 140,
#    "end": 152,
#    "pos": "ADV",
#    "tag": "RB",
#    "dep": "advmod",
#    "head": 27
#   },
#   {
#    "id": 27,
#    "start": 153,
#    "end": 155,
#    "pos": "ADP",
#    "tag": "IN",
#    "dep": "prep",
#    "head": 11
#   },
#   {
#    "id": 28,
#    "start": 156,
#    "end": 159,
#    "pos": "DET",
#    "tag": "DT",
#    "dep": "det",
#    "head": 30
#   },
#   {
#    "id": 29,
#    "start": 160,
#    "end": 170,
#    "pos": "ADJ",
#    "tag": "JJ",
#    "dep": "amod",
#    "head": 30
#   },
#   {
#    "id": 30,
#    "start": 171,
#    "end": 177,
#    "pos": "NOUN",
#    "tag": "NN",
#    "dep": "pobj",
#    "head": 27
#   },
#   {
#    "id": 31,
#    "start": 178,
#    "end": 180,
#    "pos": "ADP",
#    "tag": "IN",
#    "dep": "prep",
#    "head": 30
#   },
#   {
#    "id": 32,
#    "start": 181,
#    "end": 192,
#    "pos": "NOUN",
#    "tag": "NNS",
#    "dep": "pobj",
#    "head": 31
#   },
#   {
#    "id": 33,
#    "start": 192,
#    "end": 193,
#    "pos": "PUNCT",
#    "tag": ".",
#    "dep": "punct",
#    "head": 11
#   }
#  ]
# }
